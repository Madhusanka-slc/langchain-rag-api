# %%
import requests # pip install requests

# %%
endpoint = "http://localhost:8100/chain"
chain_type = "/invoke"
url = f"{endpoint}{chain_type}"
url
# Out:
# 'http://localhost:8100/chain/invoke'

# %%
data = {"input": "Tell about New York"}

# %%
r = requests.post(url, json=data)

# %%
r.json()['output']
# Out:
# 'New York City is noted for its significance in various cultural movements, including the Harlem Renaissance in literature and visual art, abstract expressionism in painting, and iconic music genres such as hip-hop, punk, and jazz. It is often referred to as the dance capital of the world. The city is also characterized by its fast pace, giving rise to the expression "New York minute."'
